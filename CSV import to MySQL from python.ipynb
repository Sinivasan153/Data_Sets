# %%
#CSV import to MySQL from python
import pandas as pd

AggTransByStates = pd.read_csv('AggTransByStates.csv')
AggUserByBrand = pd.read_csv('AggUserByBrand.csv')
mapTransByDistrict = pd.read_csv('mapTransByDistrict.csv')
mapUserByDistReg = pd.read_csv('mapUserByDistReg.csv')
AggUserByBrand
# Out:
#            State  Year Quater     Brand  Brand_count  Brand_percentage
# 0     chandigarh  2022     Q1    Xiaomi       118077          0.218036
# 1     chandigarh  2022     Q1      Vivo       103673          0.191438
# 2     chandigarh  2022     Q1   Samsung       100254          0.185125
# 3     chandigarh  2022     Q1      Oppo        76330          0.140948
# 4     chandigarh  2022     Q1     Apple        45080          0.083243
# ...          ...   ...    ...       ...          ...               ...
# 6727   karnataka  2019     Q4    Realme       506808          0.032941
# 6728   karnataka  2019     Q4  Motorola       498395          0.032394
# 6729   karnataka  2019     Q4    Huawei       304839          0.019814
# 6730   karnataka  2019     Q4    Lenovo       279895          0.018192
# 6731   karnataka  2019     Q4    Others      1066738          0.069334
#
# [6732 rows x 6 columns]

# %%
# !pip install mysql-connector-python

# %%
import mysql.connector as msql
from mysql.connector import Error

try:
    conn = msql.connect(host='localhost', user='root',
                        password='Kowshika@153')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("CREATE DATABASE Phonepe_Pulse")
        print("Phonepe_Pulse database is created")

except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Error while connecting to MySQL 1007 (HY000): Can't create database 'phonepe_pulse'; database exists

# %%
#Aggregated Transaction By States Data Inserting to MySQL
AggTransByStates.dtypes
# Out:
# State                 object
# Year                   int64
# Quater                object
# Transacion_type       object
# Transacion_count       int64
# Transacion_amount    float64
# dtype: object

# %%
try:
    conn = msql.connect(host='localhost',
                           database='Phonepe_Pulse', user='root',
                           password='Kowshika@153')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        
        cursor.execute('DROP TABLE IF EXISTS AggTransByStates;')
       
        cursor.execute("CREATE TABLE AggTransByStates\
                       (State varchar(100),\
                        Year int,\
                        Quater varchar(5),\
                        Transacion_type varchar(50),\
                        Transacion_count int,\
                        Transacion_amount float(50,3))")
                       
        print("AggTransByStates table is created....")
        for i,row in AggTransByStates.iterrows():
            sql = "INSERT INTO Phonepe_Pulse.AggTransByStates VALUES (%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))                        
            conn.commit()
        print("AggTransByStates values are inserted to MySQL....")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# AggTransByStates table is created....
# AggTransByStates values are inserted to MySQL....

# %%
#Aggregated Users by States Data Inserting to MySQL
AggUserByBrand.dtypes
# Out:
# State                object
# Year                  int64
# Quater               object
# Brand                object
# Brand_count           int64
# Brand_percentage    float64
# dtype: object

# %%
try:
    conn = msql.connect(host='localhost',
                           database='Phonepe_Pulse', user='root',
                           password='Kowshika@153')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        
        cursor.execute('DROP TABLE IF EXISTS AggUserByBrand;')
       
        cursor.execute("CREATE TABLE AggUserByBrand\
                       (State varchar(100),\
                        Year int,\
                        Quater varchar(5),\
                        Brand varchar(50),\
                        Brand_count int,\
                        Brand_percentage float(50,3))")
                       
        print("AggUserByBrand table is created....")
        for i,row in AggUserByBrand.iterrows():
            sql = "INSERT INTO Phonepe_Pulse.AggUserByBrand VALUES (%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))                        
            conn.commit()
        print("AggUserByBrand values are inserted to MySQL....")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# AggUserByBrand table is created....
# AggUserByBrand values are inserted to MySQL....

# %%
#Map Transaction by District Data Inserting to MySQL
mapTransByDistrict.dtypes
# Out:
# State                  object
# Year                    int64
# Quater                 object
# District               object
# Transaction_count       int64
# Transaction_amount    float64
# dtype: object

# %%
try:
    conn = msql.connect(host='localhost',
                           database='Phonepe_Pulse', user='root',
                           password='Kowshika@153')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        
        cursor.execute('DROP TABLE IF EXISTS mapTransByDistrict;')
       
        cursor.execute("CREATE TABLE mapTransByDistrict\
                       (State varchar(100),\
                        Year int,\
                        Quater varchar(5),\
                        District varchar(50),\
                        Transaction_count int,\
                        Transaction_amount float(50,3))")
                       
        print("mapTransByDistrict table is created....")
        for i,row in mapTransByDistrict.iterrows():
            sql = "INSERT INTO Phonepe_Pulse.mapTransByDistrict VALUES (%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))                        
            conn.commit()
        print("mapTransByDistrict values are inserted to MySQL....")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# mapTransByDistrict table is created....
# mapTransByDistrict values are inserted to MySQL....

# %%
#Map User by District Registration Data to MySQL
mapUserByDistReg.dtypes
# Out:
# State              object
# Year                int64
# Quater             object
# District           object
# Registered_user     int64
# App_opening         int64
# dtype: object

# %%
try:
    conn = msql.connect(host='localhost',
                           database='Phonepe_Pulse', user='root',
                           password='Kowshika@153')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        
        cursor.execute('DROP TABLE IF EXISTS mapUserByDistReg;')
       
        cursor.execute("CREATE TABLE mapUserByDistReg\
                       (State varchar(100),\
                        Year int,\
                        Quater varchar(5),\
                        District varchar(50),\
                        Registered_user int,\
                        App_opening int)")
                       
        print("mapUserByDistReg table is created....")
        for i,row in mapUserByDistReg.iterrows():
            sql = "INSERT INTO Phonepe_Pulse.mapUserByDistReg VALUES (%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))                        
            conn.commit()
        print("mapUserByDistReg values are inserted to MySQL....")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# mapUserByDistReg table is created....
# mapUserByDistReg values are inserted to MySQL....

# %%
#Fetch the Data From MySQL Table to Python
try:
    conn = msql.connect(host='localhost',
                           database='Phonepe_Pulse', user='root',
                           password='Kowshika@153')
    if conn.is_connected():
        cursor = conn.cursor()        
        cursor.execute("SELECT * FROM AggTransByStates")
        records = cursor.fetchall()
        data=pd.DataFrame(records,
                    columns=[i[0] for i  in cursor.description])

        conn.commit()
        cursor.close()
        conn.close()  
except Error as e:
    print("Error while connecting to MySQL", e)

data
# Out:
#            State  Year Quater           Transacion_type  Transacion_count  \
# 0     chandigarh  2022     Q2         Merchant payments           6136803
# 1     chandigarh  2022     Q2     Peer-to-peer payments           3489382
# 2     chandigarh  2022     Q2  Recharge & bill payments           1119367
# 3     chandigarh  2022     Q2        Financial Services              6673
# 4     chandigarh  2022     Q2                    Others             20264
# ...          ...   ...    ...                       ...               ...
# 3589   karnataka  2019     Q4         Merchant payments         114044901
# 3590   karnataka  2019     Q4     Peer-to-peer payments          93311589
# 3591   karnataka  2019     Q4  Recharge & bill payments          28862161
# 3592   karnataka  2019     Q4        Financial Services            101937
# 3593   karnataka  2019     Q4                    Others           1475664
#
#       Transacion_amount
# 0          3.919373e+09
# 1          1.254925e+10
# ...

# %%
#Data Transformation
mapUserByDistReg
# Out:
#             State  Year Quater             District  Registered_user  \
# 0      chandigarh  2022     Q2  chandigarh district           569582
# 1      chandigarh  2022     Q3  chandigarh district           598698
# 2      chandigarh  2022     Q1  chandigarh district           541549
# 3      chandigarh  2022     Q4  chandigarh district           627563
# 4      chandigarh  2018     Q2  chandigarh district           115219
# ...           ...   ...    ...                  ...              ...
# 14635   karnataka  2019     Q4      hassan district           279728
# 14636   karnataka  2019     Q4     dharwad district           452178
# 14637   karnataka  2019     Q4  shivamogga district           286945
# 14638   karnataka  2019     Q4       udupi district           220313
# 14639   karnataka  2019     Q4       gadag district           129976
#
#        App_opening
# 0          2285979
# 1          2173356
# 2          2321685
# 3         15308862
# 4                0
# ...

# %%
import numpy as np

# %%
mapUserByDistReg_filter = np.where((mapUserByDistReg['State']=='gujarat') & (mapUserByDistReg['Year']==2022))
mapUserByDistReg_filter=mapUserByDistReg.loc[mapUserByDistReg_filter]
mapUserByDistReg_filter
# Out:
#          State  Year Quater                  District  Registered_user  \
# 10740  gujarat  2022     Q2            anand district           541890
# 10741  gujarat  2022     Q2         jamnagar district           372354
# 10742  gujarat  2022     Q2  devbhumi dwarka district           130591
# 10743  gujarat  2022     Q2           rajkot district           937863
# 10744  gujarat  2022     Q2        aravallis district           206898
# ...        ...   ...    ...                       ...              ...
# 10867  gujarat  2022     Q4          navsari district           328740
# 10868  gujarat  2022     Q4            patan district           384293
# 10869  gujarat  2022     Q4          kachchh district           781383
# 10870  gujarat  2022     Q4    surendranagar district           366161
# 10871  gujarat  2022     Q4            morbi district           322150
#
#        App_opening
# 10740      7236033
# 10741     12188995
# 10742     13208562
# 10743     24500393
# ...

# %%
dist_reg = mapUserByDistReg_filter.groupby(['District']).sum(numeric_only=True)[['Registered_user','App_opening']]
dist_reg = dist_reg.reset_index()
dist_reg
# Out:
#                     District  Registered_user  App_opening
# 0         ahmadabad district         16853406    271384683
# 1            amreli district          1097147     91292834
# 2             anand district          2223101     35858979
# 3         aravallis district           847833     60861908
# 4      banas kantha district          3488916    243011480
# 5           bharuch district          3131483    109804910
# 6         bhavnagar district          2568814     74093401
# 7             botad district           726723     49081961
# 8      chhotaudepur district           358900     38201521
# 9   devbhumi dwarka district           533578     43944520
# 10            dohad district           842041     61062862
# 11      gandhinagar district          3454153     63185229
# 12      gir somnath district           944915     34407136
# 13         jamnagar district          1526442     51066974
# 14         junagadh district          1103206     43060212
# ...
