# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinivasan153/Data_Sets/blob/main/Phonepe_Pulse_Data_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Check the current working directory 
# !pwd
# Out:
# /content

# %%
# lists the contents of the current directory
# !ls
# Out:
# sample_data

# %%
# To clone the git repository, copy the github repository link
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# Cloning into 'pulse'...
# remote: Enumerating objects: 7975, done.
# remote: Counting objects: 100% (7975/7975), done.
# remote: Compressing objects: 100% (6637/6637), done.
# remote: Total 7975 (delta 2465), reused 6527 (delta 1031), pack-reused 0
# Receiving objects: 100% (7975/7975), 2.11 MiB | 9.95 MiB/s, done.
# Resolving deltas: 100% (2465/2465), done.

# %%
# !ls
# Out:
# pulse  sample_data

# %%
# !pwd
# Out:
# /content

# %%
# Changing the working directory to pulse
import os
os.chdir('/content/pulse')

# %%
# !ls
# Out:
# data  LICENSE  README.md

# %%
# Removing the unwanted folders or files in the directory
# !rm -rf LICENSE README.md

# %%
# Now we have only our required data folder
# !ls
# Out:
# data

# %%
import os
path = "/content/pulse/data/aggregated/transaction/country/india/state/" 
agg_trans_st_dir = os.listdir(path)
agg_trans_st_dir
# Out:
# ['chandigarh',
#  'manipur',
#  'chhattisgarh',
#  'andhra-pradesh',
#  'sikkim',
#  'uttarakhand',
#  'delhi',
#  'arunachal-pradesh',
#  'tamil-nadu',
#  'mizoram',
#  'odisha',
#  'jammu-&-kashmir',
#  'goa',
#  'bihar',
#  'telangana',
#  'himachal-pradesh',
#  'nagaland',
#  'maharashtra',
#  'tripura',
#  'jharkhand',
#  'puducherry',
#  'madhya-pradesh',
#  'ladakh',
#  'uttar-pradesh',
#  'rajasthan',
#  'gujarat',
#  'meghalaya',
#  'west-bengal',
#  'lakshadweep',
#  'kerala',
#  'andaman-&-nicobar-islands',
#  'haryana',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'punjab',
#  'assam',
#  'karnataka']

# %%
for i in agg_trans_st_dir:
  st_path = path+i+'/'
  print(st_path)
# Out:
# /content/pulse/data/aggregated/transaction/country/india/state/chandigarh/
# /content/pulse/data/aggregated/transaction/country/india/state/manipur/
# /content/pulse/data/aggregated/transaction/country/india/state/chhattisgarh/
# /content/pulse/data/aggregated/transaction/country/india/state/andhra-pradesh/
# /content/pulse/data/aggregated/transaction/country/india/state/sikkim/
# /content/pulse/data/aggregated/transaction/country/india/state/uttarakhand/
# /content/pulse/data/aggregated/transaction/country/india/state/delhi/
# /content/pulse/data/aggregated/transaction/country/india/state/arunachal-pradesh/
# /content/pulse/data/aggregated/transaction/country/india/state/tamil-nadu/
# /content/pulse/data/aggregated/transaction/country/india/state/mizoram/
# /content/pulse/data/aggregated/transaction/country/india/state/odisha/
# /content/pulse/data/aggregated/transaction/country/india/state/jammu-&-kashmir/
# /content/pulse/data/aggregated/transaction/country/india/state/goa/
# /content/pulse/data/aggregated/transaction/country/india/state/bihar/
# /content/pulse/data/aggregated/transaction/country/india/state/telangana/
# /content/pulse/data/aggregated/transaction/country/india/state/himachal-pradesh/
# /content/pulse/data/aggregated/transaction/country/india/state/nagaland/
# /content/pulse/data/aggregated/transaction/country/india/state/maharashtra/
# /content/pulse/data/aggregated/transaction/country/india/state/tripura/
# /content/pulse/data/aggregated/transaction/country/india/state/jharkhand/
# /content/pulse/data/aggregated/transaction/country/india/state/puducherry/
# /content/pulse/data/aggregated/transaction/country/india/state/madhya-pradesh/
# /content/pulse/data/aggregated/transaction/country/india/state/ladakh/
# /content/pulse/data/aggregated/transaction/country/india/state/uttar-pradesh/
# /content/pulse/data/aggregated/transaction/country/india/state/rajasthan/
# /content/pulse/data/aggregated/transaction/country/india/state/gujarat/
# /content/pulse/data/aggregated/transaction/country/india/state/meghalaya/
# /content/pulse/data/aggregated/transaction/country/india/state/west-bengal/
# /content/pulse/data/aggregated/transaction/country/india/state/lakshadweep/
# /content/pulse/data/aggregated/transaction/country/india/state/kerala/
# /content/pulse/data/aggregated/transaction/country/india/state/andaman-&-nicobar-islands/
# /content/pulse/data/aggregated/transaction/country/india/state/haryana/
# /content/pulse/data/aggregated/transaction/country/india/state/dadra-&-nagar-haveli-&-daman-&-diu/
# /content/pulse/data/aggregated/transaction/country/india/state/punjab/
# /content/pulse/data/aggregated/transaction/country/india/state/assam/
# /content/pulse/data/aggregated/transaction/country/india/state/karnataka/

# %%
for i in agg_trans_st_dir:
  st_path = path+i+'/'
  st_year = os.listdir(st_path)

# %%
import json

for i in agg_trans_st_dir:
  # /content/pulse/data/aggregated/transaction/country/india/state/haryana/
  st_path = path+i+'/'
  # st_year will show the years ['2018','2019','2020','2021','2022']
  st_year = os.listdir(st_path)
  for j in st_year:
    # /content/pulse/data/aggregated/transaction/country/india/state/haryana/2018/
    st_year_path = st_path+j+'/'
    st_year_dir = os.listdir(st_year_path)
    for k in st_year_dir:
      jsonFile = st_year_path+k
      data = open(jsonFile, 'r')
      D = json.load(data)
      print(D)
      break
# Out:
# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1648751400000, 'to': 1656354600000, 'transactionData': [{'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 6136803, 'amount': 3919372475.5605655}]}, {'name': 'Peer-to-peer payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 3489382, 'amount': 12549248085.111443}]}, {'name': 'Recharge & bill payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 1119367, 'amount': 792957088.5933374}]}, {'name': 'Financial Services', 'paymentInstruments': [{'type': 'TOTAL', 'count': 6673, 'amount': 8943857.181076445}]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count': 20264, 'amount': 12978651.924569944}]}]}, 'responseTimestamp': 1669732238641}
# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1522521000000, 'to': 1530124200000, 'transactionData': [{'name': 'Recharge & bill payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 224548, 'amount': 76722906.67871952}]}, {'name': 'Peer-to-peer payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 194627, 'amount': 835296156.4220204}]}, {'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 34606, 'amount': 29408471.506333277}]}, {'name': 'Financial Services', 'paymentInstruments': [{'type': 'TOTAL', 'count': 11927, 'amount': 3679451.8635118967}]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count': 13376, 'amount': 16116275.274144217}]}]}, 'responseTimestamp': 1630501487612}
# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1617215400000, 'to': 1624818600000, 'transactionData': [{'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 1926913, 'amount': 1390989390.7789688}]}, {'name': 'Peer-to-peer payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 1663559, 'amount': 6541132352.922333}]}, {'name': 'Recharge & bill payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 806710, 'amount': 467698864.6672056}]}, {'name': 'Financial Services', 'paymentInstruments': [{'type': 'TOTAL', 'count': 5502, 'amount': 7394941.032842191}]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count': 14863, 'amount': 10458390.53475552}]}]}, 'responseTimestamp': 1630501494202}
# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1585679400000, 'to': 1593282600000, 'transactionData': [{'name': 'Peer-to-peer payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 766698, 'amount': 3293060119.5471582}]}, {'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 390906, 'amount': 331423259.0003719}]}, {'name': 'Recharge & bill payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 361577, 'amount': 214425229.3354035}]}, {'name': 'Financial Services', 'paymentInstruments': [{'type': 'TOTAL', 'count': 1797, 'amount': 3982005.1176844486}]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count': 7032, 'amount': 4125116.689457224}]}]}, 'responseTimestamp': 1630501491980}
# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1554057000000, 'to': 1561660200000, 'transactionData': [{'name': 'Peer-to-peer payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 604849, 'amount': 2339922407.523348}]}, {'name': 'Recharge & bill payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 342294, 'amount': 185659011.54417655}]}, {'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 277811, 'amount': 152766864.66190332}]}, {'name': 'Financial Services', 'paymentInstruments': [{'type': 'TOTAL', 'count': 5590, 'amount': 839765.161351582}]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count':

# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1585679400000, 'to': 1593282600000, 'transactionData': [{'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 87251639, 'amount': 38463881234.4382}]}, {'name': 'Peer-to-peer payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 82118363, 'amount': 265767207470.16788}]}, {'name': 'Recharge & bill payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 43290272, 'amount': 16434890228.306221}]}, {'name': 'Financial Services', 'paymentInstruments': [{'type': 'TOTAL', 'count': 161560, 'amount': 246367207.0610708}]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count': 399878, 'amount': 192530880.1645686}]}]}, 'responseTimestamp': 1630501492024}
# {'success': True, 'code': 'SUCCESS', 'data': {'from': 1554057000000, 'to': 1561660200000, 'transactionData': [{'name': 'Peer-to-peer payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 50033334, 'amount': 142910706254.40515}]}, {'name': 'Merchant payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 44848593, 'amount': 12338599108.54726}]}, {'name': 'Recharge & bill payments', 'paymentInstruments': [{'type': 'TOTAL', 'count': 19283028, 'amount': 7745156562.557001}]}, {'name': 'Financial Services', 'paymentInstruments': [{'type': 'TOTAL', 'count': 140353, 'amount': 44871623.829314835}]}, {'name': 'Others', 'paymentInstruments': [{'type': 'TOTAL', 'count': 1096296, 'amount': 662690676.7455502}]}]}, 'responseTimestamp': 1630501490583}

# %%
D['success']
# Out:
# True

# %%
D['data']['transactionData']
# Out:
# [{'name': 'Peer-to-peer payments',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 50033334,
#     'amount': 142910706254.40515}]},
#  {'name': 'Merchant payments',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 44848593,
#     'amount': 12338599108.54726}]},
#  {'name': 'Recharge & bill payments',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 19283028,
#     'amount': 7745156562.557001}]},
#  {'name': 'Financial Services',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 140353,
#     'amount': 44871623.829314835}]},
#  {'name': 'Others',
#   'paymentInstruments': [{'type': 'TOTAL',
#     'count': 1096296,
#     'amount': 662690676.7455502}]}]

# %%
import pandas as pd

agg_trans_dict = {'State':[],
                  'Year':[],
                  'Quater':[],
                  'Transacion_type':[],
                  'Transacion_count':[],
                  'Transacion_amount':[]}

for i in agg_trans_st_dir:
  st_path = path+i+'/'
  st_year = os.listdir(st_path)
  for j in st_year:   
    st_year_path = st_path+j+'/'
    st_year_dir = os.listdir(st_year_path)
    for k in st_year_dir:
      json_path = st_year_path+k
      jsonData = open(json_path, 'r')
      Data = json.load(jsonData)
      for x in Data['data']['transactionData']:
                    Name = x['name']
                    count = x['paymentInstruments'][0]['count']
                    amount = x['paymentInstruments'][0]['amount']
                    agg_trans_dict['Transacion_type'].append(Name)
                    agg_trans_dict['Transacion_count'].append(count)
                    agg_trans_dict['Transacion_amount'].append(amount)
                    agg_trans_dict['State'].append(i)
                    agg_trans_dict['Year'].append(j)
                    agg_trans_dict['Quater'].append('Q'+k.strip('.json'))

agg_trans_df = pd.DataFrame(agg_trans_dict)
agg_trans_df
# Out:
#            State  Year Quater           Transacion_type  Transacion_count  \
# 0     chandigarh  2022     Q2         Merchant payments           6136803
# 1     chandigarh  2022     Q2     Peer-to-peer payments           3489382
# 2     chandigarh  2022     Q2  Recharge & bill payments           1119367
# 3     chandigarh  2022     Q2        Financial Services              6673
# 4     chandigarh  2022     Q2                    Others             20264
# ...          ...   ...    ...                       ...               ...
# 3589   karnataka  2019     Q4         Merchant payments         114044901
# 3590   karnataka  2019     Q4     Peer-to-peer payments          93311589
# 3591   karnataka  2019     Q4  Recharge & bill payments          28862161
# 3592   karnataka  2019     Q4        Financial Services            101937
# 3593   karnataka  2019     Q4                    Others           1475664
#
#       Transacion_amount
# 0          3.919372e+09
# 1          1.254925e+10
# 2          7.929571e+08
# 3          8.943857e+06
# 4          1.297865e+07
# ...                 ...
# 3589       3.160289e+10
# 3590       2.505629e+11
# 3591       1.218357e+10
# 3592       5.114598e+07
# 3593       6.466738e+08
#
# [3594 rows x 6 columns]

# %%
agg_trans_df.to_csv('AggTransByStates.csv',index=False)

# %%
import os
import json
import pandas as pd

path='/content/pulse/data/aggregated/user/country/india/state/'
state_dir =os.listdir(path)

user_dict = {'State': [], 'Year': [], 'Quater': [], 'Brand': [],
    'Brand_count': [], 'Brand_percentage': []}

for i in state_dir:
  state_path = path+i+'/'
  year_dir  = os.listdir(st_path)
  for j in year_dir:
    year_path = state_path+j+'/'
    file_dir = os.listdir(year_path)
    for k in file_dir:
      file_path = year_path+k
      jsonFile = open(file_path,'r')
      Data = json.load(jsonFile)
      try:
        for x in Data['data']['usersByDevice']:
          brand = x['brand']
          count = x['count']
          percentage = x['percentage']

          user_dict['Brand'].append(brand)
          user_dict['Brand_count'].append(count)
          user_dict['Brand_percentage'].append(percentage)
          user_dict['State'].append(i)
          user_dict['Year'].append(j)
          user_dict['Quater'].append('Q'+k.strip('.json'))
      except TypeError:
        pass
      
userByBrand_df = pd.DataFrame(user_dict)

userByBrand_df
# Out:
#            State  Year Quater     Brand  Brand_count  Brand_percentage
# 0     chandigarh  2022     Q1    Xiaomi       118077          0.218036
# 1     chandigarh  2022     Q1      Vivo       103673          0.191438
# 2     chandigarh  2022     Q1   Samsung       100254          0.185125
# 3     chandigarh  2022     Q1      Oppo        76330          0.140948
# 4     chandigarh  2022     Q1     Apple        45080          0.083243
# ...          ...   ...    ...       ...          ...               ...
# 6727   karnataka  2019     Q4    Realme       506808          0.032941
# 6728   karnataka  2019     Q4  Motorola       498395          0.032394
# 6729   karnataka  2019     Q4    Huawei       304839          0.019814
# 6730   karnataka  2019     Q4    Lenovo       279895          0.018192
# 6731   karnataka  2019     Q4    Others      1066738          0.069334
#
# [6732 rows x 6 columns]

# %%
userByBrand_df.to_csv('AggUserByBrand.csv',index=False)

# %%
import os
import json
import pandas as pd

path='/content/pulse/data/map/transaction/hover/country/india/state/'
state_dir =os.listdir(path)


map_trans_dict = {'State': [], 'Year': [], 'Quater': [], 'District': [],
    'Transaction_count': [], 'Transaction_amount': []}

for i in state_dir:
  state_path = path+i+'/'
  year_dir  = os.listdir(st_path)
  for j in year_dir:
    year_path = state_path+j+'/'
    file_dir = os.listdir(year_path)
    for k in file_dir:
      file_path = year_path+k
      jsonFile = open(file_path,'r')
      Data = json.load(jsonFile)
      try:
        for x in Data['data']["hoverDataList"]:
          district = x['name']
          trans_count = x['metric'][0]['count']
          trans_amount = x['metric'][0]['amount']
          map_trans_dict['District'].append(district)
          map_trans_dict['Transaction_count'].append(trans_count)
          map_trans_dict['Transaction_amount'].append(trans_amount)
          map_trans_dict['State'].append(i)
          map_trans_dict['Year'].append(j)
          map_trans_dict['Quater'].append('Q'+k.strip('.json'))
      except TypeError:
        pass
      
mapTransByDist_df = pd.DataFrame(map_trans_dict)

mapTransByDist_df
# Out:
#             State  Year Quater             District  Transaction_count  \
# 0      chandigarh  2022     Q2  chandigarh district           10772489
# 1      chandigarh  2022     Q3  chandigarh district           13478173
# 2      chandigarh  2022     Q1  chandigarh district            8600491
# 3      chandigarh  2022     Q4  chandigarh district           17904840
# 4      chandigarh  2018     Q2  chandigarh district             479084
# ...           ...   ...    ...                  ...                ...
# 14631   karnataka  2019     Q4      hassan district            1386630
# 14632   karnataka  2019     Q4     dharwad district            4934246
# 14633   karnataka  2019     Q4  shivamogga district            1782120
# 14634   karnataka  2019     Q4       udupi district            1073447
# 14635   karnataka  2019     Q4       gadag district             680196
#
#        Transaction_amount
# 0            1.728350e+10
# 1            2.055976e+10
# 2            1.517499e+10
# 3            2.787975e+10
# 4            9.612233e+08
# ...                   ...
# 14631        2.890518e+09
# 14632        6.425418e+09
# 14633        2.820880e+09
# 14634        1.392443e+09
# 14635        1.188344e+09
#
# [14636 rows x 6 columns]

# %%
mapTransByDist_df.to_csv('mapTransByDistrict.csv',index=False)

# %%
import os
import json
import pandas as pd

path='/content/pulse/data/map/user/hover/country/india/state/'
state_dir =os.listdir(path)

mapUserDictReg = {'State': [], 'Year': [], 'Quater': [], 'District': [],
    'Registered_user': [], 'App_opening': []}

for i in state_dir:
  state_path = path+i+'/'
  year_dir  = os.listdir(st_path)
  for j in year_dir:
    year_path = state_path+j+'/'
    file_dir = os.listdir(year_path)
    for k in file_dir:
      file_path = year_path+k
      jsonFile = open(file_path,'r')
      Data = json.load(jsonFile)
      try:
        for x in Data['data']["hoverData"]:
          district = x
          registeredUser =  Data['data']["hoverData"][x]["registeredUsers"]
          app_opening = Data['data']["hoverData"][x]["appOpens"]
          mapUserDictReg['District'].append(district)
          mapUserDictReg['Registered_user'].append(registeredUser)
          mapUserDictReg['App_opening'].append(app_opening)
          mapUserDictReg['State'].append(i)
          mapUserDictReg['Year'].append(j)
          mapUserDictReg['Quater'].append('Q'+k.strip('.json'))
      except TypeError:
        pass
      
mapUserByDistReg_df = pd.DataFrame(mapUserDictReg)

mapUserByDistReg_df
# Out:
#             State  Year Quater             District  Registered_user  \
# 0      chandigarh  2022     Q2  chandigarh district           569582
# 1      chandigarh  2022     Q3  chandigarh district           598698
# 2      chandigarh  2022     Q1  chandigarh district           541549
# 3      chandigarh  2022     Q4  chandigarh district           627563
# 4      chandigarh  2018     Q2  chandigarh district           115219
# ...           ...   ...    ...                  ...              ...
# 14635   karnataka  2019     Q4      hassan district           279728
# 14636   karnataka  2019     Q4     dharwad district           452178
# 14637   karnataka  2019     Q4  shivamogga district           286945
# 14638   karnataka  2019     Q4       udupi district           220313
# 14639   karnataka  2019     Q4       gadag district           129976
#
#        App_opening
# 0          2285979
# 1          2173356
# 2          2321685
# 3         15308862
# 4                0
# ...            ...
# 14635      5917518
# 14636     13718357
# 14637      6123526
# 14638      3719466
# 14639      3025624
#
# [14640 rows x 6 columns]

# %%
mapUserByDistReg_df.to_csv('mapUserByDistReg.csv',index=False)
